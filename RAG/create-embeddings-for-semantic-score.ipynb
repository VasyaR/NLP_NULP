# %%
# !pip install rank_bm25
# Out:
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rank_bm25) (1.26.4)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (4.45.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (2.4.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (0.25.1)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.20.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 10.2 MB/s eta 0:00:00
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-3.3.1

# %%
from rank_bm25 import BM25Okapi
import numpy as np
from tqdm import tqdm
import os
import pickle
import torch
import glob
import json

from sentence_transformers import SentenceTransformer

# %%
def tokenize_doc_to_str(doc: dict) -> str:
    tokenized_doc = []
    for key, value in doc.items():
        tokenized_key = key.lower().replace("_", " ")
        tokenized_doc.append(tokenized_key)
        tokenized_doc.append(':')
        if isinstance(value, str):
            tokenized_doc.extend(value)
        else:
            tokenized_doc.extend(str(value))
    return ' '.join(tokenized_doc)

# Take all json files with names that end '_processed' 
base_path = "/kaggle/input/jokerbot-rag/Kaggle_rag_data"
sbert_embeddings_path = "/kaggle/working/sbert_embeddings.pt"

docs = []
for path in glob.glob(f"{base_path}/*_processed.json"):
    with open(path, 'r') as f:
        docs.extend(json.load(f))

# Initialize SentenceTransformer and ensure it uses GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
sbert = SentenceTransformer('sentence-transformers/all-distilroberta-v1', device=device)

str_docs = [tokenize_doc_to_str(doc) for doc in docs]

sbert_embeddings = sbert.encode(str_docs, show_progress_bar=True, convert_to_tensor=True, batch_size=256)
sbert_embeddings = sbert_embeddings.cpu()  # Move to CPU before saving

torch.save(sbert_embeddings, sbert_embeddings_path)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.3k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/653 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/2938 [00:00<?, ?it/s]

# %%
# Define the path and split size
sbert_embeddings = torch.load("/kaggle/working/sbert_embeddings.pt")

output_dir = "/kaggle/working/embeddings_parts"
os.makedirs(output_dir, exist_ok=True)
split_size = 1000  # Number of rows per split
embeddings_size = sbert_embeddings.size(0)
# print(sbert_embeddings[0:5].shape)

# Split and save the tensor
for i in range(0, embeddings_size, split_size):
    end_idx = min(i + split_size, embeddings_size)
    part = sbert_embeddings[i:end_idx].clone()
    torch.save(part, os.path.join(output_dir, f"embeddings_part_{i//split_size}.pt"))

print(f"Saved all parts to {output_dir}")
# Out:
# /tmp/ipykernel_30/1355149148.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   sbert_embeddings = torch.load("/kaggle/working/sbert_embeddings.pt")
# Saved all parts to /kaggle/working/embeddings_parts

# %%
# Load and combine
loaded_parts = []
for file in sorted(os.listdir(output_dir)):
    if file.startswith("embeddings_part_") and file.endswith(".pt"):
        part_path = os.path.join(output_dir, file)
        loaded_parts.append(torch.load(part_path))

reconstructed_embeddings = torch.cat(loaded_parts, dim=0)

# Verify the shape
print("Original shape:", sbert_embeddings.shape)
print("Reconstructed shape:", reconstructed_embeddings.shape)
# Out:
# /tmp/ipykernel_30/672009738.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_parts.append(torch.load(part_path))
# Original shape: torch.Size([752114, 768])
# Reconstructed shape: torch.Size([752114, 768])

# %%
# !rm -rf /kaggle/working/embeddings_parts/*
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %%
# !rm -rf /kaggle/working/embedding_parts.zip

# %%
# !zip -r embedding_parts.zip /kaggle/working/embeddings_parts
# Out:
#   adding: kaggle/working/embeddings_parts/ (stored 0%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_271.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_451.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_734.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_387.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_360.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_682.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_481.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_173.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_532.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_578.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_351.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_212.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_417.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_375.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_221.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_146.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_372.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_278.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_353.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_664.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_158.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_751.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_571.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_262.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_87.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_499.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_18.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_46.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_207.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_122.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_436.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_538.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_282.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_378.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_629.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_6.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_690.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_636.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_497.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_300.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_240.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_687.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_150.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_310.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_610.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_135.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_737.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_294.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_546.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_359.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_567.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_368.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_398.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_691.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_162.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_281.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_88.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_171.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_64.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_386.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_352.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_471.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_188.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_565.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_705.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_279.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_347.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_251.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_395.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_663.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_625.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_503.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_222.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_745.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_662.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_748.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_669.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_8.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_606.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_30.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_611.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_391.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_309.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_551.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_491.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_91.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_659.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_144.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_742.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_599.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_558.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_716.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_327.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_51.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_702.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_515.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_580.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_514.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_314.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_704.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_301.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_489.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_507.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_95.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_620.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_403.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_179.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_71.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_692.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_594.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_747.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_100.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_364.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_435.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_223.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_264.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_322.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_380.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_201.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_255.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_414.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_197.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_430.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_366.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_713.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_710.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_133.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_180.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_630.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_712.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_152.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_660.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_604.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_477.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_143.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_521.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_650.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_569.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_2.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_339.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_654.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_12.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_445.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_433.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_45.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_52.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_326.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_313.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_107.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_111.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_98.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_564.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_459.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_193.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_244.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_537.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_250.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_113.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_637.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_552.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_325.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_249.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_562.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_634.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_357.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_425.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_182.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_711.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_155.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_731.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_129.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_486.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_439.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_47.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_58.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_371.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_356.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_526.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_275.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_420.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_108.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_627.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_640.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_406.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_457.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_494.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_25.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_241.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_99.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_59.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_16.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_732.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_717.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_148.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_699.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_422.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_488.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_530.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_680.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_277.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_549.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_613.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_465.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_750.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_467.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_550.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_709.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_130.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_708.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_228.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_329.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_746.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_726.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_320.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_198.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_50.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_590.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_574.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_667.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_214.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_318.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_76.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_31.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_105.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_248.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_174.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_612.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_511.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_553.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_5.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_297.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_377.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_96.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_203.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_584.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_426.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_177.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_528.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_151.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_265.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_635.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_75.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_70.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_238.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_539.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_444.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_608.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_487.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_719.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_285.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_220.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_156.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_370.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_102.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_363.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_392.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_647.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_596.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_531.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_237.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_165.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_304.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_671.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_346.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_437.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_384.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_80.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_455.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_229.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_311.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_258.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_463.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_672.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_56.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_679.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_24.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_718.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_492.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_1.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_233.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_508.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_666.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_615.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_164.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_614.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_119.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_41.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_296.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_131.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_440.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_421.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_441.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_462.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_234.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_324.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_728.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_7.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_183.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_399.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_740.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_61.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_159.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_292.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_21.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_97.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_194.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_536.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_289.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_703.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_211.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_273.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_191.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_298.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_469.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_626.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_73.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_224.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_269.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_472.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_342.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_32.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_172.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_393.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_79.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_29.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_517.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_449.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_284.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_661.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_461.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_81.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_90.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_505.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_707.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_261.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_735.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_287.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_350.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_319.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_431.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_408.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_302.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_519.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_752.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_115.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_140.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_270.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_656.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_217.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_365.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_86.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_649.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_495.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_118.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_643.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_388.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_139.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_544.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_678.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_524.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_695.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_170.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_128.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_555.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_727.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_743.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_288.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_484.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_340.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_11.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_442.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_247.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_456.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_577.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_132.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_55.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_195.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_639.pt (deflated 15%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_74.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_167.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_33.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_213.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_123.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_187.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_624.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_299.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_390.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_389.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_582.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_512.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_176.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_127.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_374.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_257.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_84.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_725.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_427.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_715.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_63.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_34.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_306.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_500.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_655.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_605.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_733.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_175.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_675.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_617.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_385.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_587.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_652.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_405.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_557.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_394.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_676.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_305.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_186.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_166.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_458.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_117.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_685.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_576.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_646.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_48.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_330.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_344.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_641.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_199.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_684.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_545.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_192.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_688.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_160.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_72.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_423.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_230.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_579.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_473.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_468.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_0.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_124.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_349.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_698.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_138.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_534.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_94.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_235.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_631.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_681.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_668.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_383.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_616.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_645.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_556.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_53.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_619.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_480.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_202.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_595.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_37.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_27.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_593.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_438.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_651.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_450.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_263.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_749.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_638.pt (deflated 35%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_744.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_657.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_479.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_482.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_290.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_295.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_592.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_464.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_724.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_328.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_323.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_208.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_409.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_272.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_83.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_210.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_236.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_245.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_736.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_720.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_498.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_268.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_568.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_157.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_332.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_585.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_68.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_106.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_447.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_586.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_321.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_283.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_125.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_190.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_470.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_648.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_400.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_478.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_120.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_603.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_109.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_121.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_622.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_204.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_523.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_583.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_443.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_547.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_181.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_200.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_334.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_274.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_293.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_416.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_126.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_141.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_419.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_493.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_336.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_525.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_312.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_633.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_112.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_670.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_741.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_85.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_348.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_101.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_674.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_381.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_168.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_376.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_280.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_110.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_256.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_303.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_116.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_623.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_696.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_9.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_697.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_424.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_17.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_114.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_196.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_501.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_602.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_543.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_554.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_82.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_239.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_413.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_673.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_189.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_78.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_103.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_496.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_653.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_560.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_407.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_410.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_316.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_570.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_402.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_93.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_147.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_575.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_266.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_154.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_362.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_518.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_361.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_355.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_67.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_598.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_317.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_219.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_20.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_520.pt (deflated 11%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_446.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_145.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_522.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_338.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_460.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_42.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_397.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_566.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_714.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_184.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_729.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_4.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_331.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_206.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_573.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_38.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_333.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_428.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_701.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_475.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_243.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_35.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_700.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_49.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_723.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_401.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_600.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_591.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_452.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_396.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_26.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_572.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_502.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_286.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_260.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_215.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_36.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_104.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_169.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_246.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_561.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_77.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_418.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_644.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_28.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_369.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_658.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_341.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_429.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_628.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_412.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_62.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_44.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_14.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_22.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_618.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_92.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_40.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_483.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_693.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_66.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_739.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_677.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_506.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_232.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_19.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_343.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_738.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_609.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_454.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_354.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_227.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_541.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_60.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_434.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_205.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_43.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_694.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_721.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_23.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_358.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_621.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_453.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_254.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_540.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_509.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_15.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_581.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_533.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_513.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_607.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_137.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_178.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_136.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_490.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_548.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_516.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_161.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_589.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_337.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_683.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_231.pt (deflated 8%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_415.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_65.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_448.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_185.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_13.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_706.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_252.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_466.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_89.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_39.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_722.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_504.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_665.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_242.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_267.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_527.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_259.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_563.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_535.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_510.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_216.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_642.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_307.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_559.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_10.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_686.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_226.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_142.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_209.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_597.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_153.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_601.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_404.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_632.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_315.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_69.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_335.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_149.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_54.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_730.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_379.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_218.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_291.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_276.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_134.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_373.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_57.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_308.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_474.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_485.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_542.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_411.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_529.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_476.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_367.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_588.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_382.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_253.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_689.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_225.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_432.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_3.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_345.pt (deflated 7%)
#   adding: kaggle/working/embeddings_parts/embeddings_part_163.pt (deflated 7%)
